# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree

# %%
i=load_iris()

# %%
x,y=i['data'],i['target']

# %%
x=pd.DataFrame(x,columns=['sl','sw','pl','pw'])
y=pd.DataFrame(y,columns=['species'])

# %%
import seaborn as sn
sn.scatterplot(x=x["sl"],y=x["sw"])
# Out:
# <Axes: xlabel='sl', ylabel='sw'>

# %%
sn.barplot(x=x['sl'],y=x['sw'])
# Out:
# <Axes: xlabel='sl', ylabel='sw'>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
tree.plot_tree(model,feature_names=['sl','sw','pl','pw'],class_names=["verginica",'versicolor',"setosa"])
# Out:
# [Text(0.4, 0.9, 'pl <= 2.7\ngini = 0.666\nsamples = 112\nvalue = [38, 36, 38]\nclass = verginica'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]\nclass = verginica'),
#  Text(0.5, 0.7, 'pw <= 1.7\ngini = 0.5\nsamples = 74\nvalue = [0, 36, 38]\nclass = setosa'),
#  Text(0.2, 0.5, 'pl <= 4.95\ngini = 0.102\nsamples = 37\nvalue = [0, 35, 2]\nclass = versicolor'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]\nclass = versicolor'),
#  Text(0.3, 0.3, 'pw <= 1.55\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = setosa'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = setosa'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.8, 0.5, 'pl <= 4.85\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = setosa'),
#  Text(0.7, 0.3, 'sw <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = setosa'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = setosa'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = setosa')]

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %%
f1_score(y_test,y_pred,average='micro')
# Out:
# 0.9736842105263158
